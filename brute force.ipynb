# %%
questions = {
    "PY1": "What is Python?",
    "PY2": "Python is an interpreted language. Explain.",
    "PY3": "What distinguishes lists from tuples?",
    "PY4": "What is PEP 8?",
    "PY5": "What are the Key features of Python?",
    "PY6": "How is Memory managed in Python?",
    "PY7": "What is PYTHONPATH?",
    "PY8": "What are Python Modules?",
    "PY9": "What are python namespaces?",
    "PY10": "What is scope resolution?",
    "PY11": "What is a dictionary in Python?",
    "PY12": "What are functions in Python?",
    "PY13": "What is __init__ in Python?",
    "PY14": "What are the common built-in data types in Python?",
    "PY15": "What are local variables and global variables in Python?",
    "PY16": "What is type conversion in Python?",
    "PY17": "How to install Python on Windows and set a path variable?",
    "PY18": "What is the difference between Python Arrays and lists?",
    "PY19": "Is Python case sensitive?",
    "PY20": "What does [::-1] do?",
    "PY21": "What are Python packages?",
    "PY22": "What are decorators?",
    "PY23": "Is indentation required in Python?",
    "PY24": "How does break, continue, and pass work?",
    "PY25": "How can you randomize the items of a list in place in Python?",
    "PY26": "How to comment with multiple lines in Python?",
    "PY27": "What type of language is python? Programming or scripting?",
    "PY28": "What are negative indexes and why are they used?",
    "PY29": "Explain split(), sub(), subn() methods of “re” module in Python?",
    "PY30": "What do you mean by Python literals?",
    "PY31": "What is a map function in Python?",
    "PY32": "What are generators in Python?",
    "PY33": "What are Python iterators?",
    "PY34": "Do we need to declare variables with respective data types in Python?",
    "PY35": "What are Dict and List comprehensions?",
    "PY36": "How do you write comments in Python?",
    "PY37": "Is multiple inheritance supported in Python?",
    "PY38": "What is the difference between range & xrange?",
    "PY39": "What is pickling and unpickling?",
    "PY40": "What do you understand by the word Tkinter?",
    "PY41": "Is Python fully object oriented?",
    "PY42": "Differentiate between NumPy and SciPy?",
    "PY43": "Explain all file processing modes supported in Python?",
    "PY44": "What do file-related modules in Python do? Can you name some file-related modules in Python?",
    "PY45": "Explain the use of the 'with' statement and its syntax?",
    "PY46": "Write a code to display the contents of a file in reverse?",
    "PY47": "Which of the following is an invalid statement?",
    "PY48": "Write a command to open the file c:\hello.txt for writing?",
    "PY49": "What does len() do?",
    "PY50": "What does *args and **kwargs mean in Python?",
    "PY51": "How will you remove duplicate elements from a list?",
    "PY52": "How can files be deleted in Python?",
    "PY53": "How will you read a random line in a file?",
    "PY54": "Write a Python program to count the total number of lines in a text file?",
    "PY55": "What would be the output if I run the following code block?",
    "PY56": "What is the purpose of “is”, “not” and “in” operators?",
    "PY57": "Whenever Python exits, why isn’t all the memory de-allocated?",
    "PY58": "How can the ternary operators be used in Python?",
    "PY59": "How to add values to a python array?",
    "PY60": "How to remove values to a python array?",
    "PY61": "Write a code to sort a numerical list in Python?",
    "PY62": "Can you write an efficient code to count the number of capital letters in a file?",
    "PY63": "How will you reverse a list in Python?",
    "PY64": "How will you remove the last object from a list in Python?",
    "PY65": "How can you generate random numbers in Python?",
    "PY66": "How will you convert a string to all lowercase?",
    "PY67": "Why would you use NumPy arrays instead of lists in Python?",
    "PY68": "What is polymorphism in Python?",
    "PY69": "Define encapsulation in Python?",
    "PY70": "What advantages do NumPy arrays offer over (nested) Python lists?",
    "PY71": "What is the lambda function in Python?",
    "PY72": "What is self in Python?",
    "PY73": "What is the difference between append() and extend() methods?",
    "PY74": "How does Python Flask handle database requests?",
    "PY75": "What is docstring in Python?",
    "PY76": "How is multi-threading achieved in Python?",
    "PY77": "What is slicing in Python?",
    "PY78": "What is functional programming? Does Python follow a functional programming style? If yes, list a few methods to implement functionally oriented programming in Python.",
    "PY79": "Which one of the following is not the correct syntax for creating a set in Python?",
    "PY80": "What is monkey patching in Python?",
    "PY81": "What is the difference between / and // operator in Python?",
    "PY82": "What is pandas?",
    "PY83": "What are dataframes?",
    "PY84": "How to combine dataframes in pandas?",
    "PY85": "How do you identify missing values and deal with missing values in Dataframe?",
    "PY86": "What is regression?",
    "PY87": "What is classification?",
    "PY88": "How do you split the data in train and test dataset in python?",
    "PY89": "What is SVM?"
}

# %%
basic_level_questions = {
    "PY1": "What is Python?",
    "PY2": "Python is an interpreted language. Explain.",
    "PY3": "What distinguishes lists from tuples?",
    "PY4": "What is PEP 8?",
    "PY5": "What are the key features of Python?",
    "PY6": "How is memory managed in Python?",
    "PY7": "What is PYTHONPATH?",
    "PY8": "What are Python modules?",
    "PY9": "What are Python namespaces?",
    "PY10": "What is scope resolution?",
    "PY11": "What is a dictionary in Python?",
    "PY12": "What are functions in Python?",
    "PY13": "What is __init__ in Python?",
    "PY14": "What are the common built-in data types in Python?"
}

intermediate_level_questions = {
    "PY15": "What are local variables and global variables in Python?",
    "PY16": "What is type conversion in Python?",
    "PY17": "How to install Python on Windows and set a path variable?",
    "PY18": "What is the difference between Python Arrays and lists?",
    "PY19": "Is Python case sensitive?",
    "PY20": "What does [::-1] do?",
    "PY21": "What are Python packages?",
    "PY22": "What are decorators?",
    "PY23": "Is indentation required in Python?",
    "PY24": "How do break, continue, and pass work?",
    "PY25": "How can you randomize the items of a list in place in Python?",
    "PY26": "How to comment with multiple lines in Python?",
    "PY27": "What type of language is Python? Programming or scripting?",
    "PY28": "What are negative indexes and why are they used?",
    "PY29": "Explain split(), sub(), subn() methods of 're' module in Python?",
    "PY30": "What do you mean by Python literals?"
}

advanced_level_questions = {
    "PY31": "What is a map function in Python?",
    "PY32": "What are generators in Python?",
    "PY33": "What are Python iterators?",
    "PY34": "Do we need to declare variables with respective data types in Python?",
    "PY35": "What are Dict and List comprehensions?",
    "PY36": "How do you write comments in Python?",
    "PY37": "Is multiple inheritance supported in Python?",
    "PY38": "What is the difference between range & xrange?",
    "PY39": "What is pickling and unpickling?",
    "PY40": "What do you understand by the word Tkinter?",
    "PY41": "Is Python fully object oriented?",
    "PY42": "Differentiate between NumPy and SciPy?",
    "PY43": "Explain all file processing modes supported in Python?",
    "PY44": "What do file-related modules in Python do? Can you name some file-related modules in Python?",
    "PY45": "Explain the use of the 'with' statement and its syntax?",
    "PY46": "Write a code to display the contents of a file in reverse?",
    "PY47": "Which of the following is an invalid statement?",
    "PY48": "Write a command to open the file c:\hello.txt for writing?",
    "PY49": "What does len() do?",
    "PY50": "What does *args and **kwargs mean in Python?"
}

# %%
import random

# Initialize dictionaries to store asked questions for each level
asked_questions_basic = {}
asked_questions_intermediate = {}
asked_questions_advanced = {}

# Function to select a question based on the level and avoiding repetition
def select_question(level):
    if level == "Basic":
        if len(asked_questions_basic) == len(basic_level_questions):
            return "No more new questions available in the Basic level."
        while True:
            question_key = random.choice(list(basic_level_questions.keys()))
            if question_key not in asked_questions_basic:
                asked_questions_basic[question_key] = True
                return basic_level_questions[question_key]
    elif level == "Intermediate":
        if len(asked_questions_intermediate) == len(intermediate_level_questions):
            return "No more new questions available in the Intermediate level."
        while True:
            question_key = random.choice(list(intermediate_level_questions.keys()))
            if question_key not in asked_questions_intermediate:
                asked_questions_intermediate[question_key] = True
                return intermediate_level_questions[question_key]
    elif level == "Advanced":
        if len(asked_questions_advanced) == len(advanced_level_questions):
            return "No more new questions available in the Advanced level."
        while True:
            question_key = random.choice(list(advanced_level_questions.keys()))
            if question_key not in asked_questions_advanced:
                asked_questions_advanced[question_key] = True
                return advanced_level_questions[question_key]
    else:
        return "Invalid level provided."

# Example usage:

selected_question = select_question("Basic")
print(selected_question)  # Use the selected_question variable to get the chosen question
# Out:
# What are Python namespaces?

# %%
import pyaudio
import wave

# Function to convert text to speech
def SpeakText(command):
    # Initialize the engine
    engine = pyttsx3.init()
    engine.say(command) 
    engine.runAndWait()
    

def record_audio(filename, duration):
    CHUNK = 1024
    FORMAT = pyaudio.paInt16
    CHANNELS = 1
    RATE = 44100
    RECORD_SECONDS = duration

    audio = pyaudio.PyAudio()

    stream = audio.open(format=FORMAT, channels=CHANNELS,
                        rate=RATE, input=True,
                        frames_per_buffer=CHUNK)

    print("Recording...")

    frames = []

    for i in range(0, int(RATE / CHUNK * RECORD_SECONDS)):
        data = stream.read(CHUNK)
        frames.append(data)

    print("Finished recording.")

    stream.stop_stream()
    stream.close()
    audio.terminate()

    wave_file = wave.open(filename, 'wb')
    wave_file.setnchannels(CHANNELS)
    wave_file.setsampwidth(audio.get_sample_size(FORMAT))
    wave_file.setframerate(RATE)
    wave_file.writeframes(b''.join(frames))
    wave_file.close()

if __name__ == "__main__":
    SpeakText(selected_question)
    file_name = "recorded_audio.wav"  # Change the filename as desired
    recording_duration = 7 # Change the duration (in seconds) as desired
    record_audio(file_name, recording_duration)
# Out:
# starting None
# starting None
# starting None
# starting None
# starting None
# word None 1 1071360
# word None 1 1071360
# word None 1 1071360
# word None 1 1071360
# word None 1 1071360
# word None 1 1071360
# finishing None False
# finishing None False
# finishing None False
# finishing None False
# finishing None False
# word None 1 1071360
# word None 1 1071360
# word None 1 1071360
# word None 1 1071360
# word None 1 1071360
# word None 1 1071360
# Recording...
# Finished recording.

# %%
"""
At the command line, only need to run once to install the package via pip:

$ pip install google-generativeai
"""

import google.generativeai as genai

genai.configure(api_key="AIzaSyApKK5BXpv6x41yTXubZnkkKBnQq4NLEbM")

# Set up the model
generation_config = {
  "temperature": 0.9,
  "top_p": 1,
  "top_k": 1,
  "max_output_tokens": 2048,
}

safety_settings = [
  {
    "category": "HARM_CATEGORY_HARASSMENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_HATE_SPEECH",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
]

model = genai.GenerativeModel(model_name="gemini-pro",
                              generation_config=generation_config,
                              safety_settings=safety_settings)

response = model.generate_content(input_text)
print(response.text)

# %%
# Import the required module for text 
# to speech conversion 
from gtts import gTTS 

# This module is imported so that we can 
# play the converted audio 
import os 

# The text that you want to convert to audio 
mytext = 'Welcome to geeksforgeeks!'

# Language in which you want to convert 
language = 'en'

# Passing the text and language to the engine, 
# here we have marked slow=False. Which tells 
# the module that the converted audio should 
# have a high speed 
myobj = gTTS(text=mytext, lang=language, slow=False) 

# Saving the converted audio in a mp3 file named 
# welcome 
myobj.save("welcome.mp3") 

# Playing the converted file 
os.system("mpg321 welcome.mp3")
# Out:
# 1

# %%
import speech_recognition as sr
import pyttsx3 

# Initialize the recognizer 
r = sr.Recognizer() 

# Function to convert text to speech
def SpeakText(command):
    # Initialize the engine
    engine = pyttsx3.init()
    engine.say(command) 
    engine.runAndWait()
    

# Loop infinitely for user to speak
while True: 
    # Exception handling to handle exceptions at runtime
    try:
        # Use the microphone as the source for input
        with sr.Microphone() as source2:
            # Adjust for ambient noise
            r.adjust_for_ambient_noise(source2, duration=3)
            
            # Prompt the user before listening
            print("Speak now...")
            
            # Listen for a specific duration (in seconds)
            audio2 = r.listen(source2, timeout=10)  # Change the timeout value as needed (e.g., 10 seconds)
            
            # Using Google to recognize audio
            MyText = r.recognize_google(audio2)
            MyText = MyText.lower()

            print("Did you say:", MyText)
            SpeakText(MyText)
            
    except sr.WaitTimeoutError:
        print("Listening timed out. Please speak again.")

    except sr.RequestError as e:
        print("Could not request results: {0}".format(e))
        
    except sr.UnknownValueError:
        print("Unknown error occurred.")
# Out:
# Speak now...
# Unknown error occurred.
# Speak now...
# Did you say: ok ok
# Speak now...
# Did you say: that's good
# Speak now...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 28
#      25 print("Speak now...")
#      27 # Listen for a specific duration (in seconds)
# ---> 28 audio2 = r.listen(source2, timeout=10)  # Change the timeout value as needed (e.g., 10 seconds)
#      30 # Using Google to recognize audio
#      31 MyText = r.recognize_google(audio2)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\speech_recognition\__init__.py:523, in Recognizer.listen(self, source, timeout, phrase_time_limit, snowboy_configuration)
#     520 if phrase_time_limit and elapsed_time - phrase_start_time > phrase_time_limit:
#     521     break
# --> 523 buffer = source.stream.read(source.CHUNK)
#     524 if len(buffer) == 0: break  # reached end of the stream
#     525 frames.append(buffer)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\speech_recognition\__init__.py:199, in Microphone.MicrophoneStream.read(self, size)
#     198 def read(self, size):
# --> 199     return self.pyaudio_stream.read(size, exception_on_overflow=False)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyaudio\__init__.py:570, in PyAudio.Stream.read(self, num_frames, exception_on_overflow)
#     567 if not self._is_input:
#     568     raise IOError("Not input stream",
#     569                   paCanNotReadFromAnOutputOnlyStream)
# --> 570 return pa.read_stream(self._stream, num_frames,
#     571                       exception_on_overflow)
#
# KeyboardInterrupt:
